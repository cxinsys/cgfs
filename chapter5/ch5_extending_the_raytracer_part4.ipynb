# %% [markdown]
# $Constructive Solid Geometry$

# %% [markdown]
# ![image.png](attachment:image.png)
# $$Death star --> 여집합$$
#
# ![image-2.png](attachment:image-2.png)
# $$렌즈 --> 교차점$$
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 일반적으로 선과 객체 A@B 사이의 교차점을 계산하려면 먼저 선과 A 및 B 사이의 교차점을 별도로 계산하여 각 객체, Ra 및 Rb에 대해 "변수"인 t 범위를 제공한다.
# ![image.png](attachment:image.png)
