# %% [markdown]
# # The Projection Equation (투영 방정식)

# %% [markdown]
# 앞서 구한 공식을 다시 가져오면
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# 이렇게 정의 되는데 사실 이때의 P 점들은 viewport에 있지만 여전히 3D point들입니다.

# %% [markdown]
# 따라서 캔버스 상의 좌표로 다시 표현을 해줘야 합니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 선형대수적 관점에서의 투영 방정식

# %% [markdown]
# 위 개념들은 삼각비를 이용한 Z 평면 위로의 벡터 투영을 다루었습니다.
#
# 조금 더 일반적인 상황으로 생각해보기 위해 선형대수적 관점으로도 해석을 해보았습니다.
#
# ![image.png](attachment:image.png)
#
# 그림처럼 벡터 b를 벡터 a로 투영시키면 투영 벡터p가 생깁니다. 이를 수학적 기호로 표현하면
#
# ![image-2.png](attachment:image-2.png)
# 이렇게 표현되고, 벡터 a와 벡터 e가 수직이라는 성질을 이용해
# ![image-3.png](attachment:image-3.png)
# 위와 같이 표현 할 수 있습니다.
# ![image-4.png](attachment:image-4.png)
# 정리하면 투영 행렬을 이용한 투영 벡터에 관한 공식은 이렇게 표현이 가능합니다.

# %% [markdown]
# ### 최소 제곱법

# %% [markdown]
# [예시]
# ![image.png](attachment:image.png)
#
# 예시를 활용하여 최소 제곱법을 활용해 보겠습니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 각 방정식에서 최소가 되는 해를 찾는 과정입니다.
#
# ![image-3.png](attachment:image-3.png)
#
# x에 대해 미분한 후 0이 되게 하는 x의 근사값을 찾으면 됩니다.
#
# ![image-4.png](attachment:image-4.png)
#
# 다소 차이는 있지만 어느 정도 근사한 것을 확인 할 수 있습니다.
#
# 최소 제곱법과 투영 방정식은 어떤 연관이 있을까요?
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# 다음 벡터를 통해 증명해보겠습니다.
#
# ![image-7.png](attachment:image-7.png)
#
# 결국 투영 벡터 공식에서 벡터 a에 곱해지는 계수값은 최적해를 찾아내는 것과 동일한 것이라는 걸 알 수 있습니다.
