# %% [markdown]
# # Finding P’

# %% [markdown]
# P'을 찾기위해
# 그림 9-1의 설정을 다른 각도에서 살펴봅시다.
# 그림 9-2는 X축에 서 있는 것처럼 '오른쪽'에서 본 설정 다이어그램을 보여줍니다.
# Y + 위쪽, Z + 오른쪽, X+우릴 가리키는 방향.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이때 삼각형 OP'A와 OPB를 보면 닮음인 것을 알 수 있습니다.
# 또한 닮음을 통해 아래와 같은 식이 성립하는 것을 알 수 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# P'A = P'_y, PB = P_y, OA = P'_z = d 그리고 OB = P_z 라고 설정하면 아래와 같은 방정식을 구할 수 있습니다.

# %% [markdown]
# P'_Y = (P_Y * d) / P_z

# %% [markdown]
# 그래서 위와 같은 방정식을 3차원 공간에서 Y+축을 우리가 바라보는 방향으로 생각하여 그래프를 그려보면
# ![image.png](attachment:image.png)

# %% [markdown]
# 다시 같은 방식으로 아래와 같은 추론을 할 수 있습니다.
# ![image.png](attachment:image.png)

# %% [markdown]
# Z좌표 또한 같은 방식으로 추론을 하면 이제 P'에 관련한 3개의 좌표 모두 추론을 할 수 있게 됩니다.
