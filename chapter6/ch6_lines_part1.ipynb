# %% [markdown]
# # Describing Lines

# %% [markdown]
# 점 P_0와 P_1을 지나는 선을 그리기 위해서는 직선의 방정식을 이해해야 한다.

# %% [markdown]
# ### 직선의 방정식 유도 과정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 벡터로 표현한 직선의 방정식

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 직선의 방정식 유도과정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
